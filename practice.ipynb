# %% [markdown]
# # Practice

# %% [markdown]
# ### Variable Declaration and Initialisation

# %%
a = 10
b = "name"
c = 25.64
d = True
e = 'f'

# %%
a=b=c=225
a,c,d = True,False,"25"

# %%
print(a)
print(b)
a=b=c = 2
# Out:
# True
# 225

# %%
a = "True"
print(type(a))
a = True
print(type(a))
print(a.__sizeof__())
# Out:
# <class 'str'>
# <class 'bool'>
# 28

# %%
### Python Data Types
a = 3
print(type(a))
b = 25.36e4562
print(type(a))
# Out:
# <class 'int'>
# <class 'int'>

# %%
c = True
d = 45+56j
e = 12_36.54_32
f = str(c)
print(type(f))
c = complex(12,36)
print(c.real,c.imag)
# Out:
# <class 'str'>
# 12.0 36.0

# %%
a = 0xA123C
print(int(a))
b = bin(a)
print(b)
# Out:
# 660028
# 0b10100001001000111100

# %%
price=complex(float(input("Enter Real Part=")),float(input("Enter Imaginary Part=")))
print(price)
# Out:
# (23+45j)

# %%
x = 1236
